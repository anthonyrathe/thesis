# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from os.path import dirname as dirname
import os

# %%
#test_name="test4" # 5 permutations, transaction costs incl.
test_name="stockpair_pga_single_layer_ws10_sharpediff_ext_features_100stocks" # 5 permutations, no transaction costs
data = pd.read_csv("{}.csv".format(test_name),parse_dates=['Date',])

# %%
#tickers = ['PEP','KO','KDP','MNST','cash']
tickers = data.columns[5:]
tickers = tickers[:-int('cash' in tickers)]
plt.figure(figsize=(16, 6))

for ticker in tickers:
    sns.lineplot(x=data.Date,y=data[ticker])
plt.legend(tickers)
plt.ylabel("Portfolio weight")
plt.savefig("weights.png")

# %%
plt.figure(figsize=(16, 6))

for ticker in tickers[:-1]:
    path = os.path.relpath("../../../../palantirscreener/data/raw/prices/{}.csv".format(ticker))
    price = pd.read_csv(path,index_col=0,parse_dates=True)['open']
    price = price.loc[data.Date]
    price = price.values/price.iloc[0]
    sns.lineplot(x=data.Date,y=price)
plt.legend(tickers)
plt.ylabel("Price movement")
plt.savefig("prices.png")

# %%
plt.figure(figsize=(16, 6))
for ticker in ['Profit','Base Profit']:
    sns.lineplot(x=data.Date,y=data[ticker])
plt.legend(['Agent','Buy-and-hold'])
plt.ylabel("Profit")
plt.savefig("profit.png")
